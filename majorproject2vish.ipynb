# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishhack/Copy_of_Rock_vs_Mine_Prediction.ipynb/blob/main/majorproject2vish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***California-Dataset***
#
#
# ---
# the California housing data set, which contains data drawn from the 1990 U.S. Census. The following table provides descriptions, data ranges, and data types for each feature in the data set.
# ```
#  this data set consists 10 features as coulmns and having 20640 observations as rows
# ```
# * **longitude** ---	A measure of how far west a house is; a more negative value is
# farther west
# * **latitude** --	A measure of how far north a house is; a higher value is farther north
# * **housingMedianAge** --	Median age of a house within a block; a lower number is a newer building
# * **totalRooms** --	Total number of rooms within a block
# * **totalBedrooms** --	Total number of bedrooms within a block
# * **population** --	Total number of people residing within a block
# * **households** --	Total number of households, a group of people residing within a home unit, for a block
# * **medianIncome** --	Median income for households within a block of houses (measured in tens of thousands of US Dollars)
# * **medianHouseValue** --	Median house value for households within a block (measured in US Dollars)
#
#
#
# ###**The different data types of features as follows:**
#
#   <table>
#     <tr>
#       <th colspan="1">features</th>
#       <th>Data-type</th>
#     </tr>
#     <tr >
#       <td>longitude</td>
#       <td>continuous</td>
#     </tr>
#     <tr>
#     <td>latitude</td>
#     <td>continuous</td>
#     </tr>
#     <tr>
#       <td >housing_median_age</td>
#       <td>discreate</td>
#     <tr>
#       <td>total_rooms</td>
#       <td>discreate</td>
#     <tr>
#       <td>total_bedrooms</td>
#       <td>discreate</td>
#     <tr>
#       <td>population</td>
#       <td>discreate</td>
#     <tr>
#       <td>households</td>
#       <td>discreate</td>
#     <tr>
#       <td>median_income</td>
#       <td>continuous</td>
#     <tr>
#       <td>median_house_value</td>
#       <td>continuous</td>
#     <tr>
#       <td>ocean_proximity</td>
#       <td>nominal</td>
#     </tr>
#   </table>

# %%
#import libraries -----
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#loading dataset to variabale called "data"
data = pd.read_excel("/content/housing.xlsx")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
data.describe()  #basic statestical details ----
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data['total_bedrooms'] = data['total_bedrooms'].fillna(0).astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  int64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
median_house_values = data['median_house_value']
avg_median_house_values = median_house_values.mean()
med_median_house_values = median_house_values.median()
mod_median_house_values = median_house_values.mode()[0]
left_sd_median_house_values = avg_median_house_values - np.percentile(median_house_values, 16)
right_sd_median_house_values = np.percentile(median_house_values, 84) - avg_median_house_values

sns.histplot(median_house_values, color = '#e897da',alpha = 0.3,ec = 'none', kde = True)

plt.axvline(x=avg_median_house_values, linestyle='--', label='Mean' )
plt.axvline(x=med_median_house_values, linestyle='-', label='median' )
plt.axvline(x=mod_median_house_values, linestyle='-.', label='mod' )
plt.axvline(x=left_sd_median_house_values, linestyle=':', label='lef-sd' )
plt.axvline(x=right_sd_median_house_values, linestyle=':', label='right-sd')

sns.rugplot(median_house_values, alpha = 0.025, height=0.05,  label ='individual observations') ----
plt.xlabel("Average Median House Values")
plt.ylabel('Count')
plt.title('Distribution of Median House Income')
plt.legend( loc ='upper left', fontsize = 7)
plt.show()

print('''
''')
print("null values: ",median_house_values.isnull().sum())
print(f'mode: {median_house_values.mode().tolist()}')
print(f'median: {median_house_values.median()}')
print(f'mean: {median_house_values.mean()}')
print(f'left-sd: {left_sd_median_house_values}')
print(f'right-sd: {right_sd_median_house_values}')
print('''
''')
print(''' \033[39m INSIGHTS:
  1. there are no null values in data
  2. mean > median so that it's "right skewed data or positively skewed data".
   therefore the amount of house values and count of them are inversily proportional to each other 
  3. the rugplot (indicates the individual observations) shows the extream values (outliers)
  4. the last vertical increasing data can be considered as outlier if the data is not necessary
''')
# Out:
# null values:  0
# mode: [500001]
# median: 179700.0
# mean: 206855.81690891474
# left-sd: 110331.81690891471
# right-sd: 117144.18309108526
#
#
#   INSIGHTS:
#   1. there are no null values in data
#   2. mean > median so that it's "right skewed data or positively skewed data".
#    therefore the amount of house values and count of them are inversily proportional to each other
#   3. the rugplot (indicates the individual observations) shows the extream values (outliers)
#   4. the last vertical increasing data can be considered as outlier if the data is not necessary

# %% [markdown]
# # 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
housing_median_age = data['housing_median_age']

avg_housing_median_age = housing_median_age.mean()
med_housing_median_age = housing_median_age.median()
mod_housing_median_age = housing_median_age.mode()[0]

left_sd_housing_median_age = avg_housing_median_age - np.percentile(housing_median_age, 16)
right_sd_housing_median_age = np.percentile(housing_median_age, 84) - avg_housing_median_age

sns.histplot(housing_median_age, alpha = 0.3,color='#c3acda', ec = 'none', kde = True )

plt.axvline(x=avg_housing_median_age, linestyle='--', label='Mean' )
plt.axvline(x=med_housing_median_age, linestyle='-', label='median' )
plt.axvline(x=mod_housing_median_age, linestyle='-.', label='mod' )
plt.axvline(x=left_sd_housing_median_age, linestyle=':', label='left-sd' )
plt.axvline(x=right_sd_housing_median_age, linestyle=':', label='right_sd' )

sns.rugplot(housing_median_age, alpha = 0.025, height=0.03,  label ='individual observations')

plt.xlabel("median age of houses")
plt.ylabel('Count')
plt.title('Distribution of Median House Income')
plt.legend( loc ='upper left', fontsize = 7)

plt.show()

print('''
''')
print("null values: ",housing_median_age.isnull().sum())
print(f'mode: {housing_median_age.mode().tolist()}')
print(f'median: {housing_median_age.median()}')
print(f'mean: {housing_median_age.mean()}')
print(f'left-sd: {left_sd_housing_median_age}')
print(f'right-sd: {right_sd_housing_median_age}')


print('''
''')
print(''' \033[39m INSIGHTS:
  1. there are no null values
  1. mean < median ---- so that it's "left skewed data or negtively skewed data".
  2. mean ≅  median ---- if not to be precised with float values the data is symetrical (nearly equal).
  3. left and right standard deviation also nearly equal, so it also defines as it is symetrical data
  4. the rugplot (indicates the individual observations) shows the extream values (outliers)
  3. the last vertical increasing data can be considered as outlier if the data is not necessary
''')
# Out:
# null values:  0
# mode: [52]
# median: 29.0
# mean: 28.639486434108527
# left-sd: 12.639486434108527
# right-sd: 13.360513565891473
#
#
#   INSIGHTS:
#   1. there are no null values
#   1. mean < median ---- so that it's "left skewed data or negtively skewed data".
#   2. mean ≅  median ---- if not to be precised with float values the data is symetrical (nearly equal).
#   3. left and right standard deviation also nearly equal, so it also defines as it is symetrical data
#   4. the rugplot (indicates the individual observations) shows the extream values (outliers)
#   3. the last vertical increasing data can be considered as outlier if the data is not necessary

# %% [markdown]
# # 3. Show with the help of visualization, how median_income and median_house_values are related?
#
#
# The data is continuous, having same size of data and need to be shown co-relation, so scatter plot is best for visualization,

# %%
fig = plt.figure(figsize=(15, 15))

Relation_plot = sns.jointplot(x=data['median_income'], y=data['median_house_value'],ec='none',alpha = 0.3, data=data, kind='scatter')
Relation_plot.plot_joint(sns.kdeplot, color = '#59c5dc')
Relation_plot.plot_marginals(sns.rugplot, height = -.15, alpha = 0.3 ,color = '#00b0b0', clip_on = False)
plt.axvline(x=data['median_income'].mean(), color='black', linestyle='--', label='Mean' )
plt.axvline(x=data['median_income'].median(), color='black', linestyle='-.', label='median' )
plt.axhline(y=data['median_house_value'].mean(), linestyle='--', color='black', label='mean' )
plt.axhline(y=data['median_house_value'].median(), linestyle='-.', color='black', label='median' )

plt.xlabel("Median Income")
plt.ylabel("Median House Values")
plt.legend(loc='upper left',fontsize = 5)
#plt.title("RELATIONSHIP BETWEEN MEDIAN INCOME AND MEDIAN HOUSE VALUES")

plt.show()

print('''
''')
print("mean of median house value :", data['median_house_value'].mean())
print("median of median house value :", data['median_house_value'].median())

print('''
for median income mean > median, so it right sckewed. 
for median house valeus mean > median, so it right sckewed
''')
# Out:
# mean of median house value : 206855.81690891474
# median of median house value : 179700.0
#
# for median income mean > median, so it right sckewed.
# for median house valeus mean > median, so it right sckewed

# %% [markdown]
# **INSIGHTS**:
#
#
#
#
# *   most of the data is co-related means if the median income value increases then median house values increases and viseversa.
# *   there are many outliers which aren't good for prediction accurately.
# *  5,00,000 median valued house is not co-related and median house values are linear with median income values

# %% [markdown]
# # 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
data['total_bedrooms'].isnull().value_counts()

new_df = data.dropna(subset=['total_bedrooms'])

new_df.to_excel("new_data.xlsx")
new_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# # 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
#data['total_bedrooms'].isnull().value_counts()
#False    20433
#True       207
import matplotlib.ticker as ticker

original_data = pd.read_excel("/content/housing.xlsx")
fig, (axis1,axis2 ) = plt.subplots(2,figsize=(10,5),sharey=True)
axis1.hist(original_data['total_bedrooms'].isnull().value_counts(), bins = 450)
axis1.set_title("total_bedrooms with null values")

mean_total_bedrooms = original_data['total_bedrooms'].mean()
total_bedrooms_without_null_values = original_data['total_bedrooms'].fillna(mean_total_bedrooms,inplace=False)


axis2.hist(total_bedrooms_without_null_values.isnull().value_counts(), bins = 450)
axis2.set_title("total_bedrooms without null values")

# converting scientific values to integers ------------
formatter = ticker.ScalarFormatter(useOffset=False) # 'useOffset = False' coverts to interger and 'useOffset = True' does not covert to interger
axis2.xaxis.set_major_formatter(formatter)
fig.subplots_adjust(wspace=2, hspace=0.5)

fig.tight_layout()

plt.show()

print('''

''')

print(f'total_bedrooms without null values: {total_bedrooms_without_null_values}')
print(f'total_bedrooms with null values: {original_data["total_bedrooms"]}')
# Out:
# total_bedrooms without null values: 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: float64
# total_bedrooms with null values: 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: float64

# %%
print(original_data['total_bedrooms'].isnull().value_counts())
total_bedrooms_without_null_values.isnull().value_counts())
# Out:
# False    20433
# True       207
# Name: total_bedrooms, dtype: int64
# False    20640
# Name: total_bedrooms, dtype: int64

# %% [markdown]
# # 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.
#
#
# ![5.jpg](data:image/jpeg;base64,...)

# %%
def median(x):
  n = len(x)
  sorted_data = sorted(x)
  if n %2 == 0:
    median_even = n+1 // 2
    print("median: ", sorted(x['median_even']))
  else:
    first_obe = n// 2
    secound_obe = n+2 // 2
    median_odd = first_obe + secound_obe // 2
    print("median: ", sorted(x['median_odd']))
x = data['housing_median_age'].median()
x
# Out:
# 29.0

# %%
#example ------------
x = data['housing_median_age'].median()
x
# Out:
# 29.0

# %% [markdown]
# # 7. Plot latitude versus longitude and explain your observations.
# ![image.png](data:image/png;base64,...)

# %%
sns.scatterplot(data =data ,x = data['longitude'], y = data['latitude'], color = '#9bd9b0', ec = 'black', alpha = 0.3)

plt.xlabel("latitude")
plt.ylabel("longitude")
plt.title("latitude versus longitude")
plt.show()


print('''

''')
print(''' \033[39m EXPLANATION:
  1. X-axis represents longitudes
  2. Y-axis presents latitude


INSIGHTS:
  1. In plot, the consentrated or high intensive visible region represents more populaiton or more altitude areas
  2. AND low intensive visible areas represents less population or low altitude areas, or it maybe near to water bodies like sea and ocean
  3. longitude and latitudes are in inversely proportion
''')
# Out:
#   EXPLANATION:
#   1. X-axis represents longitudes
#   2. Y-axis presents latitude
#
#
# INSIGHTS:
#   1. In plot, the consentrated or high intensive visible region represents more populaiton or more altitude areas
#   2. AND low intensive visible areas represents less population or low altitude areas, or it maybe near to water bodies like sea and ocean
#   3. longitude and latitudes are in inversely proportion

# %% [markdown]
# # 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
near_ocean_data = data[data['ocean_proximity'] == 'NEAR OCEAN']

sns.scatterplot(x=near_ocean_data['longitude'], y=near_ocean_data['latitude'], alpha=0.5)
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.title("Data set for which the ocean_proximity is ‘Near ocean’")

plt.show()

# %% [markdown]
# # 9. Find the mean and median of the median income for the data set created in question 8.

# %%
near_ocean_data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
fig, (mean_near_ocean_data,median_near_ocean_data) = plt.subplots(2,figsize=(5,7))
mean_near_ocean_data = near_ocean_data['median_income'].mean()
plt.hist(mean_near_ocean_data, bins = 50)
plt.title("mean of median_income")

print("mean: ",mean_near_ocean_data)

median_near_ocean_data = near_ocean_data['median_income'].median()
plt.hist(median_near_ocean_data, bins = 50)


print("median: ",median_near_ocean_data)
# Out:
# mean:  4.0057848006019565
# median:  3.64705

# %% [markdown]
# # 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
def get_bedroom_size(total_bedrooms):
    if total_bedrooms <= 10:
        return 'small'
    elif 11 <= total_bedrooms < 1000:
        return 'medium'
    else:
        return 'large'

data['total_bedroom_size'] = data['total_bedrooms'].apply(get_bedroom_size)
#fig, ax = plt.subplots(figsize=(15, 10))
plt.hist(data['total_bedroom_size'])
plt.show()
